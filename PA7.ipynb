# %% [markdown]
# ### PA7, Version 1, CS 150 SP23

# %% [markdown]
# ### Scientific Calcuator:
# #### a. Type the funtion: my_calc()
# #### b. Pick a number between 1 and 15 to choose the action you'd like the calcualtor to perform:
# #### 1. Addition
# #### 2. Subtraction
# #### 3. Multiplication
# #### 4. Division
# #### 5. Average
# #### 6. Square a number
# #### 7. Cube a number
# #### 8. Square root
# #### 9. Ceiling of a number
# #### 10. Floor of  number
# #### 11. Sine
# #### 12. Cosine
# #### 13. Tangent
# #### 14. PI
# #### 15. Tau

# %%
import math

def my_calc():
    choose=input("Hello! What would you like me to calculate? Enter a number between 1 & 15: ")
    
    if choose in ('1','2','3','4','5'):
        n1=float(input("Enter your first number: "))
        n2=float(input("Enter your second number: "))
        
        if choose== '1':
            print(n1, "+", n2, "=", n1+n2)
        elif choose== '2':
            print(n1, "-", n2, "=", n1-n2)
        elif choose== '3':
            print(n1, "*", n2, "=", n1*n2)
        elif choose== '4':
            print(n1, "/", n2, "=", n1/n2)
        elif choose== '5':
            print("The average of", n1,"and", n2, "is", (n1+n2)/2)
    elif choose in ('6','7','8','9','10','11','12','13'):
        number=float(input("Enter a number: "))
        
        if choose=='6':
            print(number, "squared is",number**2)
        elif choose=='7':
            print(number, "cubed is", number**3)
        elif choose=='8':
            print("The square root of", number, "is", math.sqrt(number))
        elif choose=='9':
            print("The celing of", number,"is", math.ceil(number))
        elif choose=='10':
            print("The floor of", number,"is", math.floor(number))
        elif choose=='11':
            print("The sine of", number, "is", math.sin(number))
        elif choose=='12':
            print("The cosine of", number, "is", math.cos(number))
        elif choose=='13':
            print("The tangent of", number, "is", math.tan(number))
    elif choose=='14':
            print("Pi is", math.pi)
    elif choose=='15':
            print("Tau is", math.tau)
    else:
        print("Try another number!")
    keep_going()
def keep_going():
    again=input("Do you have any other questions? Y/N: ")
    if again.upper()=='Y':
        my_calc()
    elif again.upper()=='N':
         print("Ok. See you later!")
    else:
        keep_going()

# %%
my_calc()
# Out:
# Hello! What would you like me to calculate? Enter a number between 1 & 15: 1
# Enter your first number: 10
# Enter your second number: 34
# 10.0 + 34.0 = 44.0
# Do you have any other questions? Y/N: y
# Hello! What would you like me to calculate? Enter a number between 1 & 15: 2
# Enter your first number: 12
# Enter your second number: 2
# 12.0 - 2.0 = 10.0
# Do you have any other questions? Y/N: y
# Hello! What would you like me to calculate? Enter a number between 1 & 15: 3
# Enter your first number: 12
# Enter your second number: 2
# 12.0 * 2.0 = 24.0
# Do you have any other questions? Y/N: y
# Hello! What would you like me to calculate? Enter a number between 1 & 15: 4
# Enter your first number: 4
# Enter your second number: 2
# 4.0 / 2.0 = 2.0
# Do you have any other questions? Y/N: y
# Hello! What would you like me to calculate? Enter a number between 1 & 15: 5
# Enter your first number: 12
# Enter your second number: 8
# The average of 12.0 and 8.0 is 10.0
# ...
